# %% [markdown]
# # HackDavis OSIsoft OCS Jupyter Notebook
#
# ![](https://apimgmtstelkv30lahnuj362.blob.core.windows.net/content/MediaLibrary/hackdavis/hackdavis_header.png)
#
# ## OCS-HackDavis Package Installation

# %%
# !pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple/ ocs-hackdavis==0.34.0
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple/
# Requirement already satisfied: ocs-hackdavis==0.34.0 in ./anaconda3/lib/python3.7/site-packages (0.34.0)
# Requirement already satisfied: typeguard>=2.4.1 in ./anaconda3/lib/python3.7/site-packages (from ocs-hackdavis==0.34.0) (2.7.1)
# Requirement already satisfied: pyyaml in ./anaconda3/lib/python3.7/site-packages (from ocs-hackdavis==0.34.0) (5.1.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in ./anaconda3/lib/python3.7/site-packages (from ocs-hackdavis==0.34.0) (2.8.0)
# Requirement already satisfied: backoff in ./anaconda3/lib/python3.7/site-packages (from ocs-hackdavis==0.34.0) (1.10.0)
# Requirement already satisfied: ocs-sample-library-preview==0.0.36rc0 in ./anaconda3/lib/python3.7/site-packages (from ocs-hackdavis==0.34.0) (0.0.36rc0)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.8.0->ocs-hackdavis==0.34.0) (1.12.0)
# Requirement already satisfied: requests==2.22.0 in ./anaconda3/lib/python3.7/site-packages (from ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.34.0) (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.7/site-packages (from requests==2.22.0->ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.34.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./anaconda3/lib/python3.7/site-packages (from requests==2.22.0->ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.34.0) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in ./anaconda3/lib/python3.7/site-packages (from requests==2.22.0->ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.34.0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.7/site-packages (from requests==2.22.0->ocs-sample-library-preview==0.0.36rc0->ocs-hackdavis==0.34.0) (2019.9.11)

# %% [markdown]
# ## Import functions from package `ocs_hackdavis`
#
# ### They are all described in this notebook with examples

# %%
from ocs_hackdavis import (
    ucdavis_buildings,  # list of campus buildings
    ucdavis_ceeds_of,   # list of CEED element of a building (Electricity, Steam, Chilled Water, etc)
    ucdavis_streams_of, # The list of all OCS data streams for a building and CEED pair  
    ucdavis_building_metadata,  # Metadata for a building: building code, lat/long, usage, etc.  
    ocs_stream_interpolated_data,  # Interpolated data from a stream given a time range + interpolation interval
    ucdavis_outside_temperature,  # Outside temperature at UC Davis for a given a time range + interpolation interval
)

# %% [markdown]
# ## List of buildings

# %%
buildings = ucdavis_buildings()
len(buildings), buildings[:25]  # display first 25
# Out:
# (159,
#  ['ARC Pavilion',
#   'Academic Surge Building',
#   'Activities and Recreation Center',
#   'Advanced Materials Research Laboratory',
#   'Advanced Transportation Infrastructure Research Center',
#   'Aggie Stadium',
#   'Agronomy Field Laboratory',
#   'Animal Building',
#   'Animal Resource Service J1',
#   'Animal Resource Service M3',
#   'Animal Resource Service N1',
#   'Ann E. Pitzer Center',
#   'Antique Mechanics Trailer',
#   'Aquatic Biology & Environmental Science Bldg',
#   'Art Building',
#   'Art Building Annex',
#   'Art, Music, Wright Halls',
#   'Asmundson Annex',
#   'Asmundson Hall',
#   'Bainer Hall',
#   'Bowley Head House',
#   'Briggs Hall',
#   'California Hall',
#   'Campus Data Center',
#   'Cellular Biology Laboratory'])

# %% [markdown]
# ## Function `ucdavis_ceeds_of` returns list of CEEDs for a given building
#
# ### Display them for all buildings

# %%
for num, building in enumerate(ucdavis_buildings(), 1):
    print(f"[{num}] Building: {building} ==> CEEDS: {ucdavis_ceeds_of(building)}")
# Out:
# [1] Building: ARC Pavilion ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [2] Building: Academic Surge Building ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [3] Building: Activities and Recreation Center ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [4] Building: Advanced Materials Research Laboratory ==> CEEDS: ['Electricity']
# [5] Building: Advanced Transportation Infrastructure Research Center ==> CEEDS: ['Electricity']
# [6] Building: Aggie Stadium ==> CEEDS: ['Electricity']
# [7] Building: Agronomy Field Laboratory ==> CEEDS: ['Electricity']
# [8] Building: Animal Building ==> CEEDS: ['Electricity']
# [9] Building: Animal Resource Service J1 ==> CEEDS: ['Electricity', 'Natural Gas']
# [10] Building: Animal Resource Service M3 ==> CEEDS: ['Electricity']
# [11] Building: Animal Resource Service N1 ==> CEEDS: ['Electricity']
# [12] Building: Ann E. Pitzer Center ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [13] Building: Antique Mechanics Trailer ==> CEEDS: ['Electricity']
# [14] Building: Aquatic Biology & Environmental Science Bldg ==> CEEDS: ['Electricity']
# [15] Building: Art Building ==> CEEDS: ['Electricity']
# [16] Building: Art Building Annex ==> CEEDS: ['Electricity']
# [17] Building: Art, Music, Wright Halls ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [18] Building: Asmundson Annex ==> CEEDS: ['Electricity']
# [19] Building: Asmundson Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [20] Building: Bainer Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [21] Building: Bowley Head House ==> CEEDS: ['Electricity']
# [22] Building: Briggs Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [23] Building: California Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [24] Building: Campus Data Center ==> CEEDS: ['ChilledWater', 'Electricity']
# [25] Building: Cellular Biology Laboratory ==> CEEDS: ['Electricity']
# [26] Building: Center for Companion Animal Health ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [27] Building: Center for Comparative Medicine ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [28] Building: Center for Health & Environment Clinical Medicine ==> CEEDS: ['Electricity']
# [29] Building: Center for Health & Environment Office & Laboratory ==> CEEDS: ['Electricity']
# [30] Building: Center for Health & Environment Toxic Pollutant Laboratory ==> CEEDS: ['Electricity', 'Natural Gas']
# [31] Building: Central Cage Wash Facility ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [32] Building: Chemistry ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [33] Building: Chemistry Annex ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [34] Building: Cole A ==> CEEDS: ['Electricity']
# [35] Building: Cole B ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [36] Building: Conference Center ==> CEEDS: ['Electricity']
# [37] Building: Contained Research Facility ==> CEEDS: ['Electricity']
# [38] Building: Cruess Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [39] Building: Dairy Cattle Feed ==> CEEDS: ['Electricity']
# [40] Building: Dairy Cattle Shed ==> CEEDS: ['Electricity']
# [41] Building: Dairy Tower ==> CEEDS: ['Electricity']
# [42] Building: Earth and Physical Sciences Building ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [43] Building: Environmental Services Facility Headquarters ==> CEEDS: ['Electricity']
# [44] Building: Equestrian Center Caretaker Trailer ==> CEEDS: ['Electricity']
# [45] Building: Equestrian Center Covered Arena ==> CEEDS: ['Electricity']
# [46] Building: Everson Hall ==> CEEDS: ['Electricity', 'Steam']
# [47] Building: FPS Trinchero Building ==> CEEDS: ['Electricity']
# [48] Building: Facilities Electrical Annex ==> CEEDS: ['Electricity']
# [49] Building: Freeborn Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [50] Building: Gallagher Hall ==> CEEDS: ['Electricity']
# [51] Building: Genome & Biomedical Sciences Facility ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [52] Building: Geotechnical Modeling Facility ==> CEEDS: ['Electricity']
# [53] Building: Ghausi Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [54] Building: Giedt Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [55] Building: Gourley Clinical Teaching Center ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [56] Building: Growth Chamber Building T1 ==> CEEDS: ['Electricity']
# [57] Building: Growth Chamber Building T2 ==> CEEDS: ['Electricity']
# [58] Building: Haring Hall ==> CEEDS: ['Electricity']
# [59] Building: Hart Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [60] Building: Heitman Staff Learning Center ==> CEEDS: ['Electricity']
# [61] Building: Hickey Gym ==> CEEDS: ['Electricity', 'Steam']
# [62] Building: Hickey Pool ==> CEEDS: ['Electricity', 'Steam']
# [63] Building: Hoagland Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [64] Building: Hopkins Services Center Parking Lot ==> CEEDS: ['Electricity']
# [65] Building: Hopkins Services Complex ==> CEEDS: ['Electricity']
# [66] Building: Hopkins Services Complex Auxiliary Receiving ==> CEEDS: ['Electricity']
# [67] Building: Housing Administration ==> CEEDS: ['ChilledWater', 'Electricity']
# [68] Building: Hunt Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [69] Building: Hutchison Child Development Center ==> CEEDS: ['Electricity', 'Natural Gas']
# [70] Building: Hutchison Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [71] Building: Hutchison Recreation Field Lights ==> CEEDS: ['Electricity']
# [72] Building: IET Communications Resources ==> CEEDS: ['Electricity']
# [73] Building: International Center ==> CEEDS: ['Electricity']
# [74] Building: Jackson Sustainable Winery ==> CEEDS: ['Electricity']
# [75] Building: Jungerman Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [76] Building: Kemper Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [77] Building: Kerr Hall ==> CEEDS: ['Electricity', 'Steam']
# [78] Building: King Hall ==> CEEDS: ['ChilledWater', 'Electricity']
# [79] Building: Leukemia Barn ==> CEEDS: ['Electricity']
# [80] Building: Leukemia Lab ==> CEEDS: ['Electricity']
# [81] Building: Life Sciences ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [82] Building: Maddy Lab ==> CEEDS: ['ChilledWater', 'Electricity']
# [83] Building: Mann Laboratory ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [84] Building: Mathematical Sciences Building ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [85] Building: Medical Sciences I B ==> CEEDS: ['Electricity']
# [86] Building: Medical Sciences I D ==> CEEDS: ['Electricity']
# [87] Building: Memorial Union ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [88] Building: Meyer Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [89] Building: Mrak Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [90] Building: Music Building ==> CEEDS: ['Electricity']
# [91] Building: Office of Research (1850 Research Park Drive) ==> CEEDS: ['Electricity']
# [92] Building: Olson Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [93] Building: PES Tennis Courts ==> CEEDS: ['Electricity']
# [94] Building: Parsons Seed Certification Center ==> CEEDS: ['Electricity']
# [95] Building: Pavilion Parking Structure ==> CEEDS: ['Electricity']
# [96] Building: Physical Sciences & Engineering Library ==> CEEDS: ['Electricity']
# [97] Building: Physics Building ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [98] Building: Plant & Environmental Sciences ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [99] Building: Plant Reproductive Biology Facility ==> CEEDS: ['Electricity']
# [100] Building: Primate Childhood Health & Disease Facility ==> CEEDS: ['Electricity']
# [101] Building: Primate Controlled Environment Facility (CEF) ==> CEEDS: ['Electricity']
# [102] Building: Primate Quarantine ==> CEEDS: ['Electricity']
# [103] Building: Primate Respiratory Disease Center ==> CEEDS: ['Electricity', 'Natural Gas']
# [104] Building: Primate Shop Facility ==> CEEDS: ['Electricity']
# [105] Building: Primate Virology & Immunology Laboratory ==> CEEDS: ['Electricity']
# [106] Building: Pritchard VMTH ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [107] Building: Quad Parking Structure ==> CEEDS: ['Electricity']
# [108] Building: RMI Brewery, Winery, and Food Pilot Facility ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [109] Building: Roessler Hall ==> CEEDS: ['ChilledWater', 'Electricity']
# [110] Building: Schaal Aquatic Center ==> CEEDS: ['Electricity', 'Steam']
# [111] Building: School of Education Building ==> CEEDS: ['ChilledWater', 'Electricity']
# [112] Building: Sciences Lab Building ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [113] Building: Segundo Dining Commons ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [114] Building: Segundo High Rises ==> CEEDS: ['Electricity']
# [115] Building: Segundo Regan ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [116] Building: Segundo Services Center ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [117] Building: Shields Library ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [118] Building: Shrem Museum of Art ==> CEEDS: ['ChilledWater', 'Electricity']
# [119] Building: Silo Bike Barn ==> CEEDS: ['Electricity']
# [120] Building: Social Sciences & Humanities ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [121] Building: Sprocket Building ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [122] Building: Sproul Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [123] Building: Storer Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [124] Building: Student Affairs Annex ==> CEEDS: ['Electricity']
# [125] Building: Student Community Center ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [126] Building: Student Health & Wellness Center ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [127] Building: Swine Teaching and Research Facility ==> CEEDS: ['Electricity']
# [128] Building: TAPS C&E ==> CEEDS: ['Electricity']
# [129] Building: Temporary Building 144 ==> CEEDS: ['Electricity']
# [130] Building: Temporary Building 178 ==> CEEDS: ['Electricity']
# [131] Building: Temporary Building 184 ==> CEEDS: ['Electricity']
# [132] Building: Tercero 1 ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [133] Building: Tercero 3 ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [134] Building: Tercero 4 ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [135] Building: Tercero Dining Commons ==> CEEDS: ['ChilledWater', 'Electricity']
# [136] Building: The Barn ==> CEEDS: ['Electricity']
# [137] Building: The Grove ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [138] Building: Thurman Laboratory ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [139] Building: Translational Shared Research Facility ==> CEEDS: ['Electricity']
# [140] Building: Transportation and Parking Services ==> CEEDS: ['ChilledWater', 'Electricity', 'Natural Gas']
# [141] Building: Tupper Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [142] Building: University Extension Building ==> CEEDS: ['Electricity']
# [143] Building: VMTH Surgical ==> CEEDS: ['Electricity']
# [144] Building: VMTH Ward ==> CEEDS: ['Electricity']
# [145] Building: Valley Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [146] Building: Vet Med Equine Athletic Performance Lab ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [147] Building: Vet Med Lab Animal A Beach Lab ==> CEEDS: ['Electricity']
# [148] Building: Vet Med Large Animal Facility ==> CEEDS: ['Electricity']
# [149] Building: Vet Med Student Services and Administration Center ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [150] Building: Veterinary Medicine 2 ==> CEEDS: ['Electricity', 'Steam']
# [151] Building: Voorhies Hall ==> CEEDS: ['Electricity']
# [152] Building: Walker Hall ==> CEEDS: ['Electricity']
# [153] Building: Water Science & Engineering Hydraulic L2 ==> CEEDS: ['Electricity']
# [154] Building: Watershed Science Facility ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [155] Building: Wellman Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [156] Building: Western Human Nutrition Research Center (WHNRC) ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [157] Building: Wickson Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']
# [158] Building: Wright Hall ==> CEEDS: ['Electricity']
# [159] Building: Young Hall ==> CEEDS: ['ChilledWater', 'Electricity', 'Steam']

# %% [markdown]
# ## Get the list of available streams of a building
#
# #### Default CEED is Electricity

# %%
ucdavis_streams_of("Kemper Hall")
# Out:
# {'AnnualUsage': 'PI_uni-pida-vm0_859',
#  'Cumulative Use': 'PI_uni-pida-vm0_838',
#  'Demand': 'PI_uni-pida-vm0_883',
#  'Demand_kBtu': 'PI_uni-pida-vm0_860',
#  'Electricity_EUI': 'PI_uni-pida-vm0_895',
#  'MonthlyUsage': 'PI_uni-pida-vm0_858',
#  'Rollover Check': 'PI_uni-pida-vm0_896',
#  'Rollover Count Month': 'PI_uni-pida-vm0_897',
#  'Rollover Count Year': 'PI_uni-pida-vm0_898'}

# %%
ucdavis_streams_of("Young Hall")
# Out:
# {'AnnualCost': 'PI_uni-pida-vm0_11690',
#  'AnnualUsage': 'PI_uni-pida-vm0_2164',
#  'Cumulative Use': 'PI_uni-pida-vm0_2162',
#  'Demand': 'PI_uni-pida-vm0_2300_ds2m',
#  'Demand_kBtu': 'PI_uni-pida-vm0_2165',
#  'EUI': 'PI_uni-pida-vm0_2314',
#  'Electricity_EUI': 'PI_uni-pida-vm0_2369',
#  'MonthlyUsage': 'PI_uni-pida-vm0_2163',
#  'Rollover Check': 'PI_uni-pida-vm0_2370',
#  'Rollover Count Month': 'PI_uni-pida-vm0_2371',
#  'Rollover Count Year': 'PI_uni-pida-vm0_2372'}

# %% [markdown]
# ## Get the specific stream of a building

# %%
ucdavis_streams_of("Kemper Hall", "chilledWater")["Demand"]
# Out:
# #warning: Building name "Kemper Hall" and/or CEED "chilledWater" are not valid
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/ocs_hackdavis/ocs_hackdavis.py in ucdavis_streams_of(building, ceed)
#      49     try:
# ---> 50         return building_ceeds_sds[building][ceed]
#      51     except KeyError:
#
# KeyError: 'chilledWater'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-1483ac602785> in <module>
# ----> 1 ucdavis_streams_of("Kemper Hall", "chilledWater")["Demand"]
#
# ~/anaconda3/lib/python3.7/site-packages/ocs_hackdavis/ocs_hackdavis.py in ucdavis_streams_of(building, ceed)
#      53             f'#warning: Building name "{building}" and/or CEED "{ceed}" are not valid'
#      54         )
# ---> 55         raise KeyError
#      56
#      57
#
# KeyError:

# %% [markdown]
# ## Import for OCS Sample Library and other necessary modules

# %%
from ocs_sample_library_preview import OCSClient
import configparser
import io
import json
import pandas as pd

# %% [markdown]
# ## Standard configuration file parsing and OCS client object
#
# #### Reference: https://github.com/osisoft/OSI-Samples-OCS/blob/master/basic_samples/DataViews/Python3/program.py#L150
#
# ## IMPORTANT: REPLACE CLIENT ID + SECRET BELOW BEFORE RUNNING - ASK OSISOFT PERSONEL FOR URL

# %%
config_text = u"""
; IMPORTANT: replace these values with those provided by OSIsoft
[Configurations]
Namespace = UC__Davis

[Access]
Resource = https://dat-b.osisoft.com
Tenant = 65292b6c-ec16-414a-b583-ce7ae04046d4
ApiVersion = v1-preview

[Credentials] 
ClientId = 82fca0c2-3004-42c0-81cf-cc6968df1f47
ClientSecret = 3VYy318vxlFGKVuQ4+toahSyg7IqWUVKiGHJDvH/IvY=
"""

# %%
config = configparser.ConfigParser(allow_no_value=True)
config.read_file(io.StringIO(config_text))

ocs_client = OCSClient(
    config.get("Access", "ApiVersion"),
    config.get("Access", "Tenant"),
    config.get("Access", "Resource"),
    config.get("Credentials", "ClientId"),
    config.get("Credentials", "ClientSecret"),
)

namespace_id = config.get("Configurations", "Namespace")
print(f"namespace_id: '{namespace_id}'")
# Out:
# namespace_id: 'UC__Davis'

# %% [markdown]
# ## Getting interpolated data from a stream
# 'AnnualUsage': 'PI_uni-pida-vm0_859',
#  'Cumulative Use': 'PI_uni-pida-vm0_838',
#  'Demand': 'PI_uni-pida-vm0_883',
#  'Demand_kBtu': 'PI_uni-pida-vm0_860',
#  'Electricity_EUI': 'PI_uni-pida-vm0_895',
#  'MonthlyUsage': 'PI_uni-pida-vm0_858',
#  'Rollover Check': 'PI_uni-pida-vm0_896',
#  'Rollover Count Month': 'PI_uni-pida-vm0_897',
#  'Rollover Count Year': 'PI_uni-pida-vm0_898'

# %%
# Step 1: get the stream Id 
stream_id = ucdavis_streams_of("Kemper Hall")["Rollover Count Year"]

# Step 2) request interpolated data
# NOTE 1: difference between endIndex and startIndex should be 31 days or less
# NOTE 2: interpolation interval cannot be less than 2 minutes
result1 = ocs_stream_interpolated_data(
    ocs_client,
    namespace_id,
    stream_id,
    start="2017-02-01", # UTC 
    end="2017-03-01",
    interval=60*24,  # 2 minutes
)

result1[:25]
# Out:
# [{'Timestamp': '2017-02-01T00:00:00Z', 'Value': 1.0},
#  {'Timestamp': '2017-02-02T00:00:00Z', 'Value': 1.0},
#  {'Timestamp': '2017-02-03T00:00:00Z', 'Value': 1.0},
#  {'Timestamp': '2017-02-04T00:00:00Z', 'Value': 1.0},
#  {'Timestamp': '2017-02-05T00:00:00Z', 'Value': 1.0},
#  {'Timestamp': '2017-02-06T00:00:00Z', 'Value': 1.0},
#  {'Timestamp': '2017-02-07T00:00:00Z', 'Value': 1.0},
#  {'Timestamp': '2017-02-08T00:00:00Z', 'Value': 1.0},
#  {'Timestamp': '2017-02-09T00:00:00Z', 'Value': 1.0},
#  {'Timestamp': '2017-02-10T00:00:00Z', 'Value': 1.0},
#  {'Timestamp': '2017-02-11T00:00:00Z', 'Value': 0.333333343},
#  {'Timestamp': '2017-02-12T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-13T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-14T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-15T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-16T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-17T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-18T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-19T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-20T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-21T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-22T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-23T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-24T00:00:00Z', 'Value': 0.0},
#  {'Timestamp': '2017-02-25T00:00:00Z', 'Value': 0.0}]

# %% [markdown]
# ## Transform result into a Pandas series

# %%
demand1 = pd.read_json(json.dumps(result)).set_index('Timestamp')
demand1
# Out:
#                            Value
# Timestamp
# 2017-01-01 08:00:00+00:00      1
# 2017-01-01 08:02:00+00:00      1
# 2017-01-01 08:04:00+00:00      1
# 2017-01-01 08:06:00+00:00      1
# 2017-01-01 08:08:00+00:00      1
# ...                          ...
# 2017-01-31 23:52:00+00:00      1
# 2017-01-31 23:54:00+00:00      1
# 2017-01-31 23:56:00+00:00      1
# 2017-01-31 23:58:00+00:00      1
# 2017-02-01 00:00:00+00:00      1
#
# [22081 rows x 1 columns]

# %% [markdown]
# ## Get data for next month

# %%
result = ocs_stream_interpolated_data(
    ocs_client,
    namespace_id,
    stream_id,
    start="2017-01-01", # UTC 
    end="2017-2-1",
    interval=2,  # 2 minutes
)

# %% [markdown]
# ## Transform into a Pandas time series and append to first month data

# %%
demand2 = pd.read_json(json.dumps(result)).set_index('Timestamp')
demand_2m = demand1.append(demand2)
len(demand_2m), demand_2m
# Out:
# (44162,                            Value
#  Timestamp
#  2017-01-01 08:00:00+00:00      1
#  2017-01-01 08:02:00+00:00      1
#  2017-01-01 08:04:00+00:00      1
#  2017-01-01 08:06:00+00:00      1
#  2017-01-01 08:08:00+00:00      1
#  ...                          ...
#  2017-01-31 23:52:00+00:00      1
#  2017-01-31 23:54:00+00:00      1
#  2017-01-31 23:56:00+00:00      1
#  2017-01-31 23:58:00+00:00      1
#  2017-02-01 00:00:00+00:00      1
#
#  [44162 rows x 1 columns])

# %% [markdown]
# ## There is a repeated row at the boundary of the two appended series
#
# More specifically, the bottom row of first series and first row of second series. Line below shows it:

# %%
demand_2m.loc[demand_2m.index.duplicated()]
# Out:
#                                 Value
# Timestamp
# 2017-03-01 00:00:00+00:00  258.662231

# %% [markdown]
# ## Remove duplicated row
#
# Difference in lenght (== # of rows) should be 1

# %%
new_demand = demand_2m.loc[~demand_2m.index.duplicated(keep="first")]
len(demand_2m) - len(new_demand)
# Out:
# 1

# %% [markdown]
# ## Getting a full year of data
#
# ### Reusing what we've learn so far

# %%
# Create an empty series
demand = pd.Series()
demand
# Out:
# Series([], dtype: float64)

# %%
for start_month in range(1, 12):
    start_date = f"2017-{start_month}-01"
    print(f"> processing {start_date}")
    result = ocs_stream_interpolated_data(
        ocs_client,
        namespace_id,
        stream_id,
        start=start_date,  # UTC
        end=f"2017-{start_month+1}-01",
        interval=2,  # 2 minutes
    )
    demand = demand.append(
        pd.read_json(json.dumps(result)).set_index("Timestamp", drop=True)
    )

# Note there is an additional column "0" with NaN (not a number), it will be remove in the next cell
len(demand), demand
# Out:
# > processing 2017-1-01
# > processing 2017-2-01
# /home/mostafa_shokrof/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# > processing 2017-3-01
# > processing 2017-4-01
# > processing 2017-5-01
# > processing 2017-6-01
# > processing 2017-7-01
# > processing 2017-8-01
# > processing 2017-9-01
# > processing 2017-10-01
# > processing 2017-11-01
# (240250,                             0       Value
#  2017-01-01 08:02:00+00:00 NaN  203.602783
#  2017-01-01 08:04:00+00:00 NaN  196.223251
#  2017-01-01 08:06:00+00:00 NaN  195.362305
#  2017-01-01 08:08:00+00:00 NaN  195.213913
#  2017-01-01 08:10:00+00:00 NaN  197.648666
#  ...                        ..         ...
#  2017-11-30 23:52:00+00:00 NaN  228.839342
#  2017-11-30 23:54:00+00:00 NaN  228.842742
#  2017-11-30 23:56:00+00:00 NaN  228.846142
#  2017-11-30 23:58:00+00:00 NaN  228.849542
#  2017-12-01 00:00:00+00:00 NaN  228.852943
#
#  [240250 rows x 2 columns])

# %%
# remove duplicate rows and keep only column named "Values"
demand = demand.loc[~demand.index.duplicated(keep="first")]["Value"]
len(demand), demand
# Out:
# (240240, 2017-01-01 08:02:00+00:00    203.602783
#  2017-01-01 08:04:00+00:00    196.223251
#  2017-01-01 08:06:00+00:00    195.362305
#  2017-01-01 08:08:00+00:00    195.213913
#  2017-01-01 08:10:00+00:00    197.648666
#                                  ...
#  2017-11-30 23:52:00+00:00    228.839342
#  2017-11-30 23:54:00+00:00    228.842742
#  2017-11-30 23:56:00+00:00    228.846142
#  2017-11-30 23:58:00+00:00    228.849542
#  2017-12-01 00:00:00+00:00    228.852943
#  Name: Value, Length: 240240, dtype: float64)

# %% [markdown]
# ## Building metadata

# %%
ucdavis_building_metadata(ocs_client, namespace_id, "Activities and Recreation Center")
# Out:
# {'Annual Cost': 151156.0,
#  'BuildingName': 'ARC',
#  'kWh Rate': 0.0687,
#  'Prefix': 'Activities_and_Recreation_Center_MSB',
#  'Rollover': 10000000.0,
#  'CAAN': 4799.0,
#  'Construction Date': '04/15/2002',
#  'Display Name': 'Activities and Recreation Center',
#  'Latitude': 38.5428969596,
#  'Longitude': -121.759644393,
#  'Maintained Gross Sq. Ft.': 158120.0,
#  'Primary Usage (Type)': 'REC - Athletics & Recreation'}

# %% [markdown]
# ## Get outside temperature at UC Davis
#
# ### Data for this stream starts on 2017-04-01, 19:38

# %%
# display only first 100 rows
ucdavis_outside_temperature(ocs_client, namespace_id, "2017-04-01", "2017-05-01", 2)[:100]
# Out:
# [{'Timestamp': '2017-04-02T19:38:00Z', 'Value': 73.84828},
#  {'Timestamp': '2017-04-02T19:40:00Z', 'Value': 74.04701},
#  {'Timestamp': '2017-04-02T19:42:00Z', 'Value': 74.13842},
#  {'Timestamp': '2017-04-02T19:44:00Z', 'Value': 74.0657959},
#  {'Timestamp': '2017-04-02T19:46:00Z', 'Value': 74.32633},
#  {'Timestamp': '2017-04-02T19:48:00Z', 'Value': 74.61136},
#  {'Timestamp': '2017-04-02T19:50:00Z', 'Value': 74.52496},
#  {'Timestamp': '2017-04-02T19:52:00Z', 'Value': 74.7417145},
#  {'Timestamp': '2017-04-02T19:54:00Z', 'Value': 75.06158},
#  {'Timestamp': '2017-04-02T19:56:00Z', 'Value': 75.67546},
#  {'Timestamp': '2017-04-02T19:58:00Z', 'Value': 75.66438},
#  {'Timestamp': '2017-04-02T20:00:00Z', 'Value': 75.3251953},
#  {'Timestamp': '2017-04-02T20:02:00Z', 'Value': 75.10666},
#  {'Timestamp': '2017-04-02T20:04:00Z', 'Value': 75.3027649},
#  {'Timestamp': '2017-04-02T20:06:00Z', 'Value': 75.17714},
#  {'Timestamp': '2017-04-02T20:08:00Z', 'Value': 75.3776245},
#  {'Timestamp': '2017-04-02T20:10:00Z', 'Value': 75.72016},
#  {'Timestamp': '2017-04-02T20:12:00Z', 'Value': 76.0627},
#  {'Timestamp': '2017-04-02T20:14:00Z', 'Value': 76.4052353},
#  {'Timestamp': '2017-04-02T20:16:00Z', 'Value': 76.3687744},
#  {'Timestamp': '2017-04-02T20:18:00Z', 'Value': 76.283905},
#  {'Timestamp': '2017-04-02T20:20:00Z', 'Value': 76.56729},
#  {'Timestamp': '2017-04-02T20:22:00Z', 'Value': 76.40331},
#  {'Timestamp': '2017-04-02T20:24:00Z', 'Value': 76.23934},
#  {'Timestamp': '2017-04-02T20:26:00Z', 'Value': 76.07536},
#  {'Timestamp': '2017-04-02T20:28:00Z', 'Value': 76.02366},
#  {'Timestamp': '2017-04-02T20:30:00Z', 'Value': 76.3167343},
#  {'Timestamp': '2017-04-02T20:32:00Z', 'Value': 76.6098},
#  {'Timestamp': '2017-04-02T20:34:00Z', 'Value': 76.90288},
#  {'Timestamp': '2017-04-02T20:36:00Z', 'Value': 76.88543},
#  {'Timestamp': '2017-04-02T20:38:00Z', 'Value': 76.99735},
#  {'Timestamp': '2017-04-02T20:40:00Z', 'Value': 77.06408},
#  {'Timestamp': '2017-04-02T20:42:00Z', 'Value': 76.60142},
#  {'Timestamp': '2017-04-02T20:44:00Z', 'Value': 76.54569},
#  {'Timestamp': '2017-04-02T20:46:00Z', 'Value': 76.86503},
#  {'Timestamp': '2017-04-02T20:48:00Z', 'Value': 77.34797},
#  {'Timestamp': '2017-04-02T20:50:00Z', 'Value': 77.2989},
#  {'Timestamp': '2017-04-02T20:52:00Z', 'Value': 77.43853},
#  {'Timestamp': '2017-04-02T20:54:00Z', 'Value': 77.0929642},
#  {'Timestamp': '2017-04-02T20:56:00Z', 'Value': 77.37465},
#  {'Timestamp': '2017-04-02T20:58:00Z', 'Value': 77.74258},
#  {'Timestamp': '2017-04-02T21:00:00Z', 'Value': 77.538475},
#  {'Timestamp': '2017-04-02T21:02:00Z', 'Value': 77.4124146},
#  {'Timestamp': '2017-04-02T21:04:00Z', 'Value': 77.52545},
#  {'Timestamp': '2017-04-02T21:06:00Z', 'Value': 77.63849},
#  {'Timestamp': '2017-04-02T21:08:00Z', 'Value': 77.75153},
#  {'Timestamp': '2017-04-02T21:10:00Z', 'Value': 77.86457},
#  {'Timestamp': '2017-04-02T21:12:00Z', 'Value': 77.79135},
#  {'Timestamp': '2017-04-02T21:14:00Z', 'Value': 77.7103958},
#  {'Timestamp': '2017-04-02T21:16:00Z', 'Value': 77.79623},
#  {'Timestamp': '2017-04-02T21:18:00Z', 'Value': 78.06092},
#  {'Timestamp': '2017-04-02T21:20:00Z', 'Value': 78.27333},
#  {'Timestamp': '2017-04-02T21:22:00Z', 'Value': 78.35957},
#  {'Timestamp': '2017-04-02T21:24:00Z', 'Value': 78.445816},
#  {'Timestamp': '2017-04-02T21:26:00Z', 'Value': 78.2373352},
#  {'Timestamp': '2017-04-02T21:28:00Z', 'Value': 78.5590439},
#  {'Timestamp': '2017-04-02T21:30:00Z', 'Value': 78.88076},
#  {'Timestamp': '2017-04-02T21:32:00Z', 'Value': 78.69378},
#  {'Timestamp': '2017-04-02T21:34:00Z', 'Value': 78.92347},
#  {'Timestamp': '2017-04-02T21:36:00Z', 'Value': 79.05099},
#  {'Timestamp': '2017-04-02T21:38:00Z', 'Value': 78.85023},
#  {'Timestamp': '2017-04-02T21:40:00Z', 'Value': 79.01709},
#  {'Timestamp': '2017-04-02T21:42:00Z', 'Value': 79.1247253},
#  {'Timestamp': '2017-04-02T21:44:00Z', 'Value': 78.98966},
#  {'Timestamp': '2017-04-02T21:46:00Z', 'Value': 78.85461},
#  {'Timestamp': '2017-04-02T21:48:00Z', 'Value': 79.05868},
#  {'Timestamp': '2017-04-02T21:50:00Z', 'Value': 79.29029},
#  {'Timestamp': '2017-04-02T21:52:00Z', 'Value': 79.15353},
#  {'Timestamp': '2017-04-02T21:54:00Z', 'Value': 79.48146},
#  {'Timestamp': '2017-04-02T21:56:00Z', 'Value': 79.7267},
#  {'Timestamp': '2017-04-02T21:58:00Z', 'Value': 79.84753},
#  {'Timestamp': '2017-04-02T22:00:00Z', 'Value': 79.69689},
#  {'Timestamp': '2017-04-02T22:02:00Z', 'Value': 79.67676},
#  {'Timestamp': '2017-04-02T22:04:00Z', 'Value': 79.68827},
#  {'Timestamp': '2017-04-02T22:06:00Z', 'Value': 79.79684},
#  {'Timestamp': '2017-04-02T22:08:00Z', 'Value': 79.9054},
#  {'Timestamp': '2017-04-02T22:10:00Z', 'Value': 80.01398},
#  {'Timestamp': '2017-04-02T22:12:00Z', 'Value': 80.19668},
#  {'Timestamp': '2017-04-02T22:14:00Z', 'Value': 80.51108},
#  {'Timestamp': '2017-04-02T22:16:00Z', 'Value': 80.58406},
#  {'Timestamp': '2017-04-02T22:18:00Z', 'Value': 80.78938},
#  {'Timestamp': '2017-04-02T22:20:00Z', 'Value': 80.77789},
#  {'Timestamp': '2017-04-02T22:22:00Z', 'Value': 80.84128},
#  {'Timestamp': '2017-04-02T22:24:00Z', 'Value': 81.21132},
#  {'Timestamp': '2017-04-02T22:26:00Z', 'Value': 81.58137},
#  {'Timestamp': '2017-04-02T22:28:00Z', 'Value': 81.76573},
#  {'Timestamp': '2017-04-02T22:30:00Z', 'Value': 81.30953},
#  {'Timestamp': '2017-04-02T22:32:00Z', 'Value': 81.022934},
#  {'Timestamp': '2017-04-02T22:34:00Z', 'Value': 80.940506},
#  {'Timestamp': '2017-04-02T22:36:00Z', 'Value': 81.44313},
#  {'Timestamp': '2017-04-02T22:38:00Z', 'Value': 81.15181},
#  {'Timestamp': '2017-04-02T22:40:00Z', 'Value': 81.2296753},
#  {'Timestamp': '2017-04-02T22:42:00Z', 'Value': 81.4692},
#  {'Timestamp': '2017-04-02T22:44:00Z', 'Value': 81.708725},
#  {'Timestamp': '2017-04-02T22:46:00Z', 'Value': 81.59292},
#  {'Timestamp': '2017-04-02T22:48:00Z', 'Value': 81.56713},
#  {'Timestamp': '2017-04-02T22:50:00Z', 'Value': 81.64826},
#  {'Timestamp': '2017-04-02T22:52:00Z', 'Value': 81.72939},
#  {'Timestamp': '2017-04-02T22:54:00Z', 'Value': 81.81053},
#  {'Timestamp': '2017-04-02T22:56:00Z', 'Value': 81.89166}]

# %% [markdown]
# ## Plotting data with Plotly Express
#
# **Plotly Express (https://plot.ly/python/plotly-express/) is a very good plotting library with easy path to web app deployment with its DASH (https://plot.ly/dash/) companion**

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading https://files.pythonhosted.org/packages/8e/ce/6ea5683c47b682bffad39ad41d10913141b560b1b875a90dbc6abe3f4fa9/plotly-4.4.1-py2.py3-none-any.whl (7.3MB)
#      |████████████████████████████████| 7.3MB 3.3MB/s eta 0:00:01
# Collecting retrying>=1.3.3 (from plotly)
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Requirement already satisfied: six in ./anaconda3/lib/python3.7/site-packages (from plotly) (1.12.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-cp37-none-any.whl size=11429 sha256=c3d8a903edbc7fdf74b70310cc9a5023545dde714ba1ddc70ab70456fda5741e
#   Stored in directory: /home/mostafa_shokrof/.cache/pip/wheels/d7/a9/33/acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-4.4.1 retrying-1.3.3

# %%
import plotly.express as px

# %% [markdown]
# ## Select two days of demand data and transform into tidy dataframe format

# %%
df = demand['2017-03-01':'2017-03-02'].to_frame().reset_index()
df.columns = ['Time', 'Demand']
df
# Out:
#                           Time      Demand
# 0    2017-03-01 00:00:00+00:00  258.662231
# 1    2017-03-01 00:02:00+00:00  261.630829
# 2    2017-03-01 00:04:00+00:00  247.635773
# 3    2017-03-01 00:06:00+00:00  252.180191
# 4    2017-03-01 00:08:00+00:00  248.544693
# ...                        ...         ...
# 1435 2017-03-02 23:50:00+00:00  252.279266
# 1436 2017-03-02 23:52:00+00:00  253.621201
# 1437 2017-03-02 23:54:00+00:00  265.473969
# 1438 2017-03-02 23:56:00+00:00  259.356354
# 1439 2017-03-02 23:58:00+00:00  255.979462
#
# [1440 rows x 2 columns]

# %% [markdown]
# ## Graph

# %%
fig = px.line(df, x="Time", y="Demand")
fig.show()
# Out:
# <div>
#
#
#             <div id="eca21785-636f-47b8-8eaa-224c1711ed39" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eca21785-636f-47b8-8eaa-224c1711ed39")) {
#                     Plotly.newPlot(
#                         'eca21785-636f-47b8-8eaa-224c1711ed39',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Time=%{x}<br>Demand=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2017-03-01T00:00:00", "2017-03-01T00:02:00", "2017-03-01T00:04:00", "2017-03-01T00:06:00", "2017-03-01T00:08:00", "2017-03-01T00:10:00", "2017-03-01T00:12:00", "2017-03-01T00:14:00", "2017-03-01T00:16:00", "2017-03-01T00:18:00", "2017-03-01T00:20:00", "2017-03-01T00:22:00", "2017-03-01T00:24:00", "2017-03-01T00:26:00", "2017-03-01T00:28:00", "2017-03-01T00:30:00", "2017-03-01T00:32:00", "2017-03-01T00:34:00", "2017-03-01T00:36:00", "2017-03-01T00:38:00", "2017-03-01T00:40:00", "2017-03-01T00:42:00", "2017-03-01T00:44:00", "2017-03-01T00:46:00", "2017-03-01T00:48:00", "2017-03-01T00:50:00", "2017-03-01T00:52:00", "2017-03-01T00:54:00", "2017-03-01T00:56:00", "2017-03-01T00:58:00", "2017-03-01T01:00:00", "2017-03-01T01:02:00", "2017-03-01T01:04:00", "2017-03-01T01:06:00", "2017-03-01T01:08:00", "2017-03-01T01:10:00", "2017-03-01T01:12:00", "2017-03-01T01:14:00", "2017-03-01T01:16:00", "2017-03-01T01:18:00", "2017-03-01T01:20:00", "2017-03-01T01:22:00", "2017-03-01T01:24:00", "2017-03-01T01:26:00", "2017-03-01T01:28:00", "2017-03-01T01:30:00", "2017-03-01T01:32:00", "2017-03-01T01:34:00", "2017-03-01T01:36:00", "2017-03-01T01:38:00", "2017-03-01T01:40:00", "2017-03-01T01:42:00", "2017-03-01T01:44:00", "2017-03-01T01:46:00", "2017-03-01T01:48:00", "2017-03-01T01:50:00", "2017-03-01T01:52:00", "2017-03-01T01:54:00", "2017-03-01T01:56:00", "2017-03-01T01:58:00", "2017-03-01T02:00:00", "2017-03-01T02:02:00", "2017-03-01T02:04:00", "2017-03-01T02:06:00", "2017-03-01T02:08:00", "2017-03-01T02:10:00", "2017-03-01T02:12:00", "2017-03-01T02:14:00", "2017-03-01T02:16:00", "2017-03-01T02:18:00", "2017-03-01T02:20:00", "2017-03-01T02:22:00", "2017-03-01T02:24:00", "2017-03-01T02:26:00", "2017-03-01T02:28:00", "2017-03-01T02:30:00", "2017-03-01T02:32:00", "2017-03-01T02:34:00", "2017-03-01T02:36:00", "2017-03-01T02:38:00", "2017-03-01T02:40:00", "2017-03-01T02:42:00", "2017-03-01T02:44:00", "2017-03-01T02:46:00", "2017-03-01T02:48:00", "2017-03-01T02:50:00", "2017-03-01T02:52:00", "2017-03-01T02:54:00", "2017-03-01T02:56:00", "2017-03-01T02:58:00", "2017-03-01T03:00:00", "2017-03-01T03:02:00", "2017-03-01T03:04:00", "2017-03-01T03:06:00", "2017-03-01T03:08:00", "2017-03-01T03:10:00", "2017-03-01T03:12:00", "2017-03-01T03:14:00", "2017-03-01T03:16:00", "2017-03-01T03:18:00", "2017-03-01T03:20:00", "2017-03-01T03:22:00", "2017-03-01T03:24:00", "2017-03-01T03:26:00", "2017-03-01T03:28:00", "2017-03-01T03:30:00", "2017-03-01T03:32:00", "2017-03-01T03:34:00", "2017-03-01T03:36:00", "2017-03-01T03:38:00", "2017-03-01T03:40:00", "2017-03-01T03:42:00", "2017-03-01T03:44:00", "2017-03-01T03:46:00", "2017-03-01T03:48:00", "2017-03-01T03:50:00", "2017-03-01T03:52:00", "2017-03-01T03:54:00", "2017-03-01T03:56:00", "2017-03-01T03:58:00", "2017-03-01T04:00:00", "2017-03-01T04:02:00", "2017-03-01T04:04:00", "2017-03-01T04:06:00", "2017-03-01T04:08:00", "2017-03-01T04:10:00", "2017-03-01T04:12:00", "2017-03-01T04:14:00", "2017-03-01T04:16:00", "2017-03-01T04:18:00", "2017-03-01T04:20:00", "2017-03-01T04:22:00", "2017-03-01T04:24:00", "2017-03-01T04:26:00", "2017-03-01T04:28:00", "2017-03-01T04:30:00", "2017-03-01T04:32:00", "2017-03-01T04:34:00", "2017-03-01T04:36:00", "2017-03-01T04:38:00", "2017-03-01T04:40:00", "2017-03-01T04:42:00", "2017-03-01T04:44:00", "2017-03-01T04:46:00", "2017-03-01T04:48:00", "2017-03-01T04:50:00", "2017-03-01T04:52:00", "2017-03-01T04:54:00", "2017-03-01T04:56:00", "2017-03-01T04:58:00", "2017-03-01T05:00:00", "2017-03-01T05:02:00", "2017-03-01T05:04:00", "2017-03-01T05:06:00", "2017-03-01T05:08:00", "2017-03-01T05:10:00", "2017-03-01T05:12:00", "2017-03-01T05:14:00", "2017-03-01T05:16:00", "2017-03-01T05:18:00", "2017-03-01T05:20:00", "2017-03-01T05:22:00", "2017-03-01T05:24:00", "201 ...

# %% [markdown]
# ### For more info on tidy format and other visualization libraries
#
# Tidy: https://tomaugspurger.github.io/modern-5-tidy.html
#
# Visualization: https://tomaugspurger.github.io/modern-6-visualization

# %% [markdown]
# ## Test error code
#
# ### Bad argument of the right type

# %%
# should fail
ucdavis_ceeds_of("Bad Building")
# Out:
# #warning: "Bad Building" is not a valid building name
